# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanwew/indoor-instace-segmentation/blob/main/yolact/Yolact_resnet_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/farhanwew/indoor-instace-segmentation.git
# Out:
# Cloning into 'indoor-instace-segmentation'...
# remote: Enumerating objects: 1140, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 1140 (delta 5), reused 9 (delta 3), pack-reused 1127 (from 2)
# Receiving objects: 100% (1140/1140), 62.30 MiB | 33.99 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
# %cd /content/indoor-instace-segmentation/yolact
# Out:
# /content/indoor-instace-segmentation/yolact

# %%
# !ls
# Out:
# backbone.py	 eval.py   panoptic-indoor-segmentation-5  train.py
# CHANGELOG.md	 external  README.md			   utils
# data		 layers    run_coco_eval.py		   web
# environment.yml  LICENSE   scripts			   yolact.py

# %%
# !wget https://huggingface.co/dbolya/yolact-initial-weights/resolve/main/resnet101_reducedfc.pth
# Out:
# --2025-11-13 05:24:49--  https://huggingface.co/dbolya/yolact-initial-weights/resolve/main/resnet101_reducedfc.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.23, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !mv resnet101_reducedfc.pth weights/resnet101_reducedfc.pth

# %%
# !python train.py --config=yolact_panoptic_indoor_config
# Out:
# Streaming output truncated to the last 5000 lines.
#    box |  0.11 |  0.34 |  0.21 |  0.18 |  0.10 |  0.08 |  0.06 |  0.05 |  0.04 |  0.01 |  0.00 |
#   mask |  0.02 |  0.07 |  0.04 |  0.02 |  0.02 |  0.02 |  0.01 |  0.01 |  0.01 |  0.00 |  0.00 |
# -------+-------+-------+-------+-------+-------+-------+-------+-------+-------+-------+-------+
#
# [  3]     150 || B: 4.701 | C: 6.652 | M: 5.725 | S: 2.528 | T: 19.606 || ETA: 5 days, 19:39:29 || timer: 0.527
# [  3]     160 || B: 4.695 | C: 6.445 | M: 5.731 | S: 2.484 | T: 19.355 || ETA: 5 days, 18:05:05 || timer: 0.517
# [  3]     170 || B: 4.659 | C: 6.300 | M: 5.588 | S: 2.427 | T: 18.974 || ETA: 5 days, 16:40:45 || timer: 0.514
# [  3]     180 || B: 4.610 | C: 6.189 | M: 5.583 | S: 2.375 | T: 18.756 || ETA: 5 days, 15:27:05 || timer: 0.517
# [  3]     190 || B: 4.587 | C: 6.097 | M: 6.012 | S: 2.310 | T: 19.006 || ETA: 5 days, 14:22:12 || timer: 0.516
# ...

# %%
# !cp -r "/content/indoor-instace-segmentation/." "/content/drive/MyDrive/indoor - seg/"
