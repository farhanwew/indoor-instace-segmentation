# %% [markdown]
# <a href="https://colab.research.google.com/github/farhanwew/indoor-instace-segmentation/blob/main/Yolo%2011/Instance_Segmentation_yolo_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the required packages for YOLO11 and Comet ML
# !pip install ultralytics comet_ml torch torchvision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 75.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 771.9/771.9 kB 61.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.3.2
#     Uninstalling python-box-7.3.2:
#       Successfully uninstalled python-box-7.3.2
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ZACzFJOvzbToDyklrMEb")
project = rf.workspace("panopticindoor").project("panoptic-indoor-segmentation")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 128.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to panoptic-indoor-segmentation-5 in yolov11:: 100%|██████████| 1856/1856 [00:00<00:00, 6123.68it/s]

# %%
# Set your Comet Api Key
from google.colab import userdata
comet = userdata.get('OPIK_API_KEY')

# %%
# !export COMET_API_KEY=comet

# %%
import comet_ml

# %%
comet_ml.login(
    workspace = "panoptic-indoor-segmentation",
    project_name="Yolo 11 seg",
    api_key = comet,

)
# Out:
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# # 1

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-seg.pt")  # load a pretrained model (recommended for training)


# Train the model
results = model.train(data="/content/panoptic-indoor-segmentation-5/data.yaml", epochs=200, imgsz=640)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# # 2

# %%
from comet_ml import Experiment

exp = Experiment(
    workspace="panoptic-indoor-segmentation",
    project_name="Yolo 11 seg",
    api_key=comet,
    name="Yolo YOLO11m-seg"
)
# lalu log metric / parameter seperti biasa
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/panoptic-indoor-segmentation/yolo-11-seg/51add4737f9b4c0e8fc1ef3d0c9d63b4
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.

# %%
from ultralytics import YOLO

# Load a model
model2 = YOLO("yolo11m-seg.pt")  # load a pretrained model (recommended for training)


# Train the model
results2 = model2.train(data="/content/panoptic-indoor-segmentation-5/data.yaml", epochs=200, imgsz=640)
# Out:
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# # 3

# %%
from ultralytics import YOLO

# Load a model
model3 = YOLO("yolo11l-seg.pt")  # load a pretrained model (recommended for training)


# Train the model
results3 = model3.train(data="/content/panoptic-indoor-segmentation-5/data.yaml", epochs=100, imgsz=640)
# Out:
# ...
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# # 4

# %%
from ultralytics import YOLO

# Load a model
model4 = YOLO("yolo11x-seg.pt")  # load a pretrained model (recommended for training)


# Train the model
results4 = model4.train(data="/content/panoptic-indoor-segmentation-5/data.yaml", epochs=200, imgsz=640)
# Out:
# Ultralytics 8.3.225 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# ...
